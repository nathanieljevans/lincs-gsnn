# %%
import pandas as pd 
from matplotlib import pyplot as plt 
import seaborn as sbn
import numpy as np
import statsmodels.api as sm

# %%
expr = pd.read_csv('~/local/data/ccle/OmicsExpressionTPMLogp1HumanProteinCodingGenes.csv')
expr.head()
# Out:
#    Unnamed: 0 SequencingID     ModelID IsDefaultEntryForModel  \
# 0           0   CDS-010xbm  ACH-001113                    Yes
# 1           1   CDS-02TzJp  ACH-001289                    Yes
# 2           2   CDS-0693hw  ACH-001339                    Yes
# 3           3   CDS-07Plat  ACH-001619                     No
# 4           4   CDS-08FOcu  ACH-001979                    Yes
#
#   ModelConditionID IsDefaultEntryForMC  TSPAN6 (7105)  TNMD (64102)  \
# 0   MC-001113-k2lR                 Yes       4.956577      0.000000
# 1   MC-001289-BpdI                 Yes       4.954992      0.617243
# 2   MC-001339-5nRN                 Yes       3.421952      0.000000
# 3   MC-001619-IR6I                  No       5.196729      0.000000
# 4   MC-001979-E3qW                 Yes       4.651643      0.000000
#
#    DPM1 (8813)  SCYL3 (57147)  ...  ATXN8 (724066)  SMIM42 (117981789)  \
# 0     7.577648       3.179411  ...             0.0                 0.0
# 1     7.334747       2.783576  ...             0.0                 0.0
# 2     7.546069       2.615880  ...             0.0                 0.0
# 3     6.362268       2.144996  ...             0.0                 0.0
# 4     5.946408       2.454515  ...             0.0                 0.0
#
#    NPBWR1 (2831)  ACTL10 (170487)  RNF228 (122319436)  PANO1 (101927423)  \
# 0       0.414727         0.077634            1.113094           0.411901
# 1       0.029840         0.000000            1.262156           1.026871
# 2       0.127768         0.105594            0.413829           0.540575
# 3       0.075396         0.932918            0.000000           0.511978
# 4       0.012012         0.000000            1.006470           0.729221
#
#    HRURF (120766137)  PRRC2B (84726)  F8A2 (474383)  F8A1 (8263)
# 0                0.0        5.134808       1.214541     4.315653
# 1                0.0        5.951231       0.007227     4.251060
# 2                0.0        4.205971       0.030894     2.783448
# 3                0.0        4.510747       3.223597     5.106595
# 4                0.0        4.922916       0.150926     4.661556
#
# [5 rows x 19221 columns]

# %%
expr.columns[expr.columns.str.contains('ETV1')]
# Out:
# Index(['ETV1 (2115)'], dtype='object')

# %%
target_mirna = 'ETV1 (2115)' #  'ETS1 (2113)' #'FOXO3 (2309)' 
target_drug = 'BRD-K12343256'

expr = expr.rename(columns={'ModelID': 'DepMap_ID'})
cell_info = pd.read_csv('~/local/data/ccle_info.txt', sep=',')[['DepMap_ID', 'CCLE_Name', 'lineage', 'primary_disease', 'Subtype']].dropna()
expr = expr.merge(cell_info, left_on='DepMap_ID', right_on='DepMap_ID', how='left')
expr = expr.set_index('DepMap_ID')
expr.head()
# Out:
#             Unnamed: 0 SequencingID IsDefaultEntryForModel ModelConditionID  \
# DepMap_ID
# ACH-001113           0   CDS-010xbm                    Yes   MC-001113-k2lR
# ACH-001289           1   CDS-02TzJp                    Yes   MC-001289-BpdI
# ACH-001339           2   CDS-0693hw                    Yes   MC-001339-5nRN
# ACH-001619           3   CDS-07Plat                     No   MC-001619-IR6I
# ACH-001979           4   CDS-08FOcu                    Yes   MC-001979-E3qW
#
#            IsDefaultEntryForMC  TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  \
# DepMap_ID
# ACH-001113                 Yes       4.956577      0.000000     7.577648
# ACH-001289                 Yes       4.954992      0.617243     7.334747
# ACH-001339                 Yes       3.421952      0.000000     7.546069
# ACH-001619                  No       5.196729      0.000000     6.362268
# ACH-001979                 Yes       4.651643      0.000000     5.946408
#
#             SCYL3 (57147)  FIRRM (55732)  ...  RNF228 (122319436)  \
# DepMap_ID                                 ...
# ACH-001113       3.179411       4.765742  ...            1.113094
# ACH-001289       2.783576       3.736280  ...            1.262156
# ACH-001339       2.615880       4.476233  ...            0.413829
# ACH-001619       2.144996       3.087183  ...            0.000000
# ACH-001979       2.454515       1.852111  ...            1.006470
#
#             PANO1 (101927423)  HRURF (120766137)  PRRC2B (84726)  \
# DepMap_ID
# ACH-001113           0.411901                0.0        5.134808
# ACH-001289           1.026871                0.0        5.951231
# ACH-001339           0.540575                0.0        4.205971
# ACH-001619           0.511978                0.0        4.510747
# ACH-001979           0.729221                0.0        4.922916
#
#             F8A2 (474383)  F8A1 (8263)             CCLE_Name      lineage  \
# DepMap_ID
# ACH-001113       1.214541     4.315653          LC1SQSF_LUNG         lung
# ACH-001289       0.007227     4.251060  COGAR359_SOFT_TISSUE  soft_tissue
# ACH-001339       0.030894     2.783448          COLO794_SKIN         skin
# ACH-001619       3.223597     5.106595   OCUG1_BILIARY_TRACT    bile_duct
# ACH-001979       0.150926     4.661556                   NaN          NaN
#
#                primary_disease  \
# DepMap_ID
# ACH-001113         Lung Cancer
# ACH-001289            Rhabdoid
# ACH-001339         Skin Cancer
# ACH-001619  Gallbladder Cancer
# ACH-001979                 NaN
#
#                                                       Subtype
# DepMap_ID
# ACH-001113  Non-Small Cell Lung Cancer (NSCLC), Squamous C...
# ACH-001289            Atypical Teratoid Rhabdoid Tumor (ATRT)
# ACH-001339                                           Melanoma
# ACH-001619                                     Adenocarcinoma
# ACH-001979                                                NaN
#
# [5 rows x 19224 columns]

# %%
resp = pd.read_csv('~/local/data/ccle/sanger-dose-response.csv')
resp = resp[lambda x: x.BROAD_ID == target_drug]
resp.head()
# Out:
#        DATASET  COSMIC_ID  DRUG_ID  MIN_CONC  MAX_CONC  RMSE_PUBLISHED  \
# 257171   GDSC1     683665     1372  0.003906       1.0        0.119773
# 257172   GDSC1     684052     1372  0.003906       1.0        0.249754
# 257173   GDSC1     684055     1372  0.003906       1.0        0.079643
# 257174   GDSC1     684057     1372  0.003906       1.0        0.036387
# 257175   GDSC1     684059     1372  0.003906       1.0        0.063823
#
#         Z_SCORE_PUBLISHED  IC50_PUBLISHED  AUC_PUBLISHED  ARXSPAN_ID  \
# 257171           0.800808        2.481571       0.957176  ACH-002270
# 257172           0.423259        0.907994       0.883520  ACH-000052
# 257173           0.759437        2.222696       0.932690  ACH-002104
# 257174           1.308943        9.602803       0.968449  ACH-002106
# 257175           0.741538        2.119239       0.923213  ACH-002108
#
#          DRUG_NAME       BROAD_ID  upper_limit      ec50     slope  \
# 257171  TRAMETINIB  BRD-K12343256     1.256407  0.077573 -0.052521
# 257172  TRAMETINIB  BRD-K12343256     1.095369  0.251481 -0.071063
# 257173  TRAMETINIB  BRD-K12343256     0.988113  0.179408 -1.159792
# 257174  TRAMETINIB  BRD-K12343256     1.046024  0.188491 -0.131159
# 257175  TRAMETINIB  BRD-K12343256     1.278697  0.376466 -0.129156
#
#         lower_limit       auc  log2.ic50       mse        R2
# 257171     0.522920  0.891740        NaN  0.000590  0.375831
# 257172     0.388402  0.759300        NaN  0.001246  0.319947
# 257173     0.787311  0.922274        NaN  0.001470  0.781707
# 257174     0.888291  0.972795        NaN  0.000075  0.565207
# 257175     0.441299  0.907830        NaN  0.002214  0.552942

# %%
df = expr.merge(resp, left_on='DepMap_ID', right_on='ARXSPAN_ID', how='left')
df = df.assign(zscore_expr=lambda x: (x[target_mirna] - x[target_mirna].mean()) / x[target_mirna].std())
df = df.assign(zscore_auc=lambda x: (x.auc - x.auc.mean()) / x.auc.std())
df.head()
# Out:
#    Unnamed: 0 SequencingID IsDefaultEntryForModel ModelConditionID  \
# 0           0   CDS-010xbm                    Yes   MC-001113-k2lR
# 1           1   CDS-02TzJp                    Yes   MC-001289-BpdI
# 2           2   CDS-0693hw                    Yes   MC-001339-5nRN
# 3           3   CDS-07Plat                     No   MC-001619-IR6I
# 4           4   CDS-08FOcu                    Yes   MC-001979-E3qW
#
#   IsDefaultEntryForMC  TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  \
# 0                 Yes       4.956577      0.000000     7.577648
# 1                 Yes       4.954992      0.617243     7.334747
# 2                 Yes       3.421952      0.000000     7.546069
# 3                  No       5.196729      0.000000     6.362268
# 4                 Yes       4.651643      0.000000     5.946408
#
#    SCYL3 (57147)  FIRRM (55732)  ...  upper_limit  ec50  slope  lower_limit  \
# 0       3.179411       4.765742  ...          NaN   NaN    NaN          NaN
# 1       2.783576       3.736280  ...          NaN   NaN    NaN          NaN
# 2       2.615880       4.476233  ...          NaN   NaN    NaN          NaN
# 3       2.144996       3.087183  ...          NaN   NaN    NaN          NaN
# 4       2.454515       1.852111  ...          NaN   NaN    NaN          NaN
#
#    auc  log2.ic50  mse  R2  zscore_expr  zscore_auc
# 0  NaN        NaN  NaN NaN    -0.157173         NaN
# 1  NaN        NaN  NaN NaN     1.530234         NaN
# 2  NaN        NaN  NaN NaN     1.506226         NaN
# 3  NaN        NaN  NaN NaN     0.694562         NaN
# 4  NaN        NaN  NaN NaN     2.163424         NaN
#
# [5 rows x 19246 columns]

# %%
plt.figure() 
sbn.scatterplot(x='zscore_expr', y='Z_SCORE_PUBLISHED', data=df) 
sbn.regplot(x='zscore_expr', y='Z_SCORE_PUBLISHED', data=df, scatter=False, color='black')
plt.show()

# %%
df__ = df[lambda x: x.CCLE_Name.str.contains('MCF7') \
    | x.CCLE_Name.str.contains('BT20') \
        | x.CCLE_Name.str.contains('MDAMB231') \
            | x.CCLE_Name.str.contains('T47D')][['DATASET', 'CCLE_Name', 'Z_SCORE_PUBLISHED', 'auc', 'zscore_expr', target_mirna]]

df__.style.hide()
# Out:
# <style type="text/css">
# </style>
# <table id="T_40d7f">
#   <thead>
#     <tr>
#       <th id="T_40d7f_level0_col0" class="col_heading level0 col0" >DATASET</th>
#       <th id="T_40d7f_level0_col1" class="col_heading level0 col1" >CCLE_Name</th>
#       <th id="T_40d7f_level0_col2" class="col_heading level0 col2" >Z_SCORE_PUBLISHED</th>
#       <th id="T_40d7f_level0_col3" class="col_heading level0 col3" >auc</th>
#       <th id="T_40d7f_level0_col4" class="col_heading level0 col4" >zscore_expr</th>
#       <th id="T_40d7f_level0_col5" class="col_heading level0 col5" >ETV1 (2115)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_40d7f_row0_col0" class="data row0 col0" >GDSC1</td>
#       <td id="T_40d7f_row0_col1" class="data row0 col1" >MCF7_BREAST</td>
#       <td id="T_40d7f_row0_col2" class="data row0 col2" >1.311511</td>
#       <td id="T_40d7f_row0_col3" class="data row0 col3" >0.976778</td>
#       <td id="T_40d7f_row0_col4" class="data row0 col4" >-1.202963</td>
#       <td id="T_40d7f_row0_col5" class="data row0 col5" >0.147275</td>
#     </tr>
#     <tr>
#       <td id="T_40d7f_row1_col0" class="data row1 col0" >GDSC2</td>
#       <td id="T_40d7f_row1_col1" class="data row1 col1" >MCF7_BREAST</td>
#       <td id="T_40d7f_row1_col2" class="data row1 col2" >1.761750</td>
#       <td id="T_40d7f_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_40d7f_row1_col4" class="data row1 col4" >-1.202963</td>
#       <td id="T_40d7f_row1_col5" class="data row1 col5" >0.147275</td>
#     </tr>
#     <tr>
#       <td id="T_40d7f_row2_col0" class="data row2 col0" >GDSC1</td>
#       <td id="T_40d7f_row2_col1" class="data row2 col1" >MDAMB231_BREAST</td>
#       <td id="T_40d7f_row2_col2" class="data row2 col2" >-0.586737</td>
#       <td id="T_40d7f_row2_col3" class="data row2 col3" >0.603333</td>
#       <td id="T_40d7f_row2_col4" class="data row2 col4" >1.347760</td>
#       <td id="T_40d7f_row2_col5" class="data row2 col5" >5.018260</td>
#     </tr>
#     <tr>
#       <td id="T_40d7f_row3_col0" class="data row3 col0" >GDSC2</td>
#       <td id="T_40d7f_row3_col1" class="data row3 col1" >MDAMB231_BREAST</td>
#       <td id="T_40d7f_row3_col2" class="data row3 col2" >-0.472021</td>
#       <td id="T_40d7f_row3_col3" class="data row3 col3" >0.745774</td>
#       <td id="T_40d7f_row3_col4" class="data row3 col4" >1.347760</td>
#       <td id="T_40d7f_row3_col5" class="data row3 col5" >5.018260</td>
#     </tr>
#     <tr>
#       <td id="T_40d7f_row4_col0" class="data row4 col0" >GDSC1</td>
#       <td id="T_40d7f_row4_col1" class="data row4 col1" >MCF7_BREAST</td>
#       <td id="T_40d7f_row4_col2" class="data row4 col2" >1.311511</td>
#       <td id="T_40d7f_row4_col3" class="data row4 col3" >0.976778</td>
#       <td id="T_40d7f_row4_col4" class="data row4 col4" >-1.202971</td>
#       <td id="T_40d7f_row4_col5" class="data row4 col5" >0.147260</td>
#     </tr>
#     <tr>
#       <td id="T_40d7f_row5_col0" class="data row5 col0" >GDSC2</td>
#       <td id="T_40d7f_row5_col1" class="data row5 col1" >MCF7_BREAST</td>
#       <td id="T_40d7f_row5_col2" class="data row5 col2" >1.761750</td>
#       <td id="T_40d7f_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_40d7f_row5_col4" class="data row5 col4" >-1.202971</td>
#       <td id="T_40d7f_row5_col5" class="data row5 col5" >0.147260</td>
#     </tr>
#     <tr>
#       <td id="T_40d7f_row6_col0" class="data row6 col0" >GDSC1</td>
#       <td id="T_40d7f_row6_col1" class="data row6 col1" >T47D_BREAST</td>
#       <td id="T_40d7f_row6_col2" class="data row6 col2" >1.176727</td>
#       <td id="T_40d7f_row6_col3" class="data row6 col3" >0.937388</td>
#       <td id="T_40d7f_row6_col4" class="data row6 col4" >-0.801523</td>
#       <td id="T_40d7f_row6_col5" class="data row6 col5" >0.913884</td>
#     </tr>
#     <tr>
#       <td id="T_40d7f_row7_col0" class="data row7 col0" >GDSC2</td>
#       <td id="T_40d7f_row7_col1" class="data row7 col1" >T47D_BREAST</td>
#       <td id="T_40d7f_row7_col2" class="data row7 col2" >1.530974</td>
#       <td id="T_40d7f_row7_col3" class="data row7 col3" >0.933038</td>
#       <td id="T_40d7f_row7_col4" class="data row7 col4" >-0.801523</td>
#       <td id="T_40d7f_row7_col5" class="data row7 col5" >0.913884</td>
#     </tr>
#     <tr>
#       <td id="T_40d7f_row8_col0" class="data row8 col0" >GDSC1</td>
#       <td id="T_40d7f_row8_col1" class="data row8 col1" >BT20_BREAST</td>
#       <td id="T_40d7f_row8_col2" class="data row8 col2" >0.180402</td>
#       <td id="T_40d7f_row8_col3" class="data row8 col3" >0.755402</td>
#       <td id="T_40d7f_row8_col4" class="data row8 col4" >0.029929</td>
#       <td id="T_40d7f_row8_col5" class="data row8 col5" >2.501666</td>
#     </tr>
#     <tr>
#       <td id="T_40d7f_row9_col0" class="data row9 col0" >GDSC2</td>
#       <td id="T_40d7f_row9_col1" class="data row9 col1" >BT20_BREAST</td>
#       <td id="T_40d7f_row9_col2" class="data row9 col2" >0.194446</td>
#       <td id="T_40d7f_row9_col3" class="data row9 col3" >0.854801</td>
#       <td id="T_40d7f_row9_col4" class="data row9 col4" >0.029929</td>
#       <td id="T_40d7f_row9_col5" class="data row9 col5" >2.501666</td>
#     </tr>
#   </tbody>
# </table>

# %%
target_resp = 'Z_SCORE_PUBLISHED' 
target_expr = 'zscore_expr'
target_dataset = 'GDSC1'

df_breast = df[lambda x: (x.primary_disease == 'Breast Cancer') & (x.DATASET == target_dataset)][[target_expr, target_resp]].dropna()

r_spearman = df_breast.corr(method='spearman').values[0, 1] 

reg = sm.OLS(df_breast[target_resp], sm.add_constant(df_breast[target_expr])).fit()
pval = reg.pvalues[1]


plt.figure() 
sbn.scatterplot(x=target_expr, y=target_resp, data=df[lambda x: x.primary_disease == 'Breast Cancer'], hue='Subtype') 
sbn.regplot(x=target_expr, y=target_resp, data=df[lambda x: x.primary_disease == 'Breast Cancer'], scatter=False, color='black', label=f'pval={pval:.2e}, r={r_spearman:.2f}')
plt.legend()
plt.xlabel(f'z-score log2(miRNA+1) expression ({target_mirna})')
plt.ylabel(f'published z-score response ({target_drug})')
plt.show()
# Out:
# /tmp/ipykernel_1226/170729498.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pval = reg.pvalues[1]

# %%
from statannotations.Annotator import Annotator

df_breast = df_breast.assign(expr_cat = lambda x: pd.cut(x[target_expr], bins=[-np.inf, -1, 1, np.inf], labels=['low', 'medium', 'high']))

plt.figure()
ax = sbn.boxplot(x='expr_cat', y=target_resp, data=df_breast)

plt.xlabel(f'z-score log2(miRNA+1) expression ({target_mirna})')
plt.ylabel(f'published z-score response ({target_drug})')

# Add significance annotations
pairs = [('low', 'medium'), ('medium', 'high'), ('low', 'high')]
annotator = Annotator(ax, pairs, data=df_breast, x='expr_cat', y=target_resp)
annotator.configure(test='Mann-Whitney', text_format='star', loc='inside')
annotator.apply_and_annotate()

plt.show()
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# low vs. medium: Mann-Whitney-Wilcoxon test two-sided, P_val:6.003e-03 U_stat=2.650e+02
# medium vs. high: Mann-Whitney-Wilcoxon test two-sided, P_val:3.715e-01 U_stat=6.000e+01
# low vs. high: Mann-Whitney-Wilcoxon test two-sided, P_val:1.424e-02 U_stat=5.500e+01

# %% [markdown]
# # distribution of correlations

# %%
expr = pd.read_csv('~/local/data/ccle/OmicsExpressionTPMLogp1HumanProteinCodingGenes.csv')

expr = expr.rename(columns={'ModelID': 'DepMap_ID'})
cell_info = pd.read_csv('~/local/data/ccle_info.txt', sep=',')[['DepMap_ID', 'CCLE_Name', 'lineage', 'primary_disease', 'Subtype']].dropna()
expr = expr.merge(cell_info, left_on='DepMap_ID', right_on='DepMap_ID', how='left')
expr = expr.set_index('DepMap_ID')

expr[expr.columns[5:-4]] = expr[expr.columns[5:-4]].apply(lambda x: (x - x.mean()) / x.std())

resp = pd.read_csv('~/local/data/ccle/sanger-dose-response.csv')
resp = resp[lambda x: x.BROAD_ID == target_drug]

df = expr.merge(resp, left_on='DepMap_ID', right_on='ARXSPAN_ID', how='left')

df = df[lambda x: (x.primary_disease == 'Breast Cancer') & (x.DATASET == target_dataset)]

# %%
mrna_genes = expr.columns[5:-4].tolist() 

df2 = df[mrna_genes + ['Z_SCORE_PUBLISHED']]
corr_mat = df2.corr(method='spearman')

# %%
df2.head()
# Out:
#      TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  FIRRM (55732)  \
# 36        0.025964     -0.184924    -0.870147       2.606829       0.040241
# 84        0.030948     -0.104819     1.788478       0.887770       0.016684
# 103       0.272037     -0.184924    -0.802416       2.867278       0.594481
# 118       0.332640     -0.184924    -0.168422       0.171909       0.702415
# 122       0.043574     -0.184924     0.164884       2.194128      -0.551825
#
#      FGR (2268)  CFH (3075)  FUCA2 (2519)  GCLC (2729)  NFYA (4800)  ...  \
# 36    -0.350946   -0.975354     -0.242580     0.814368    -0.308075  ...
# 84    -0.343191   -0.967021      0.254761     0.665128    -0.191157  ...
# 103   -0.310923   -0.892956      1.070378     0.572551     0.280241  ...
# 118   -0.287636    0.275190      0.692606    -0.236965     0.082651  ...
# 122   -0.303490   -0.950820     -0.391063     0.440514     0.631258  ...
#
#      SMIM42 (117981789)  NPBWR1 (2831)  ACTL10 (170487)  RNF228 (122319436)  \
# 36            -0.176023      -0.466388         0.418054           -0.452774
# 84            -0.176023      -0.451924        -0.948024           -0.503194
# 103           -0.176023      -0.466388         2.621327           -0.549638
# 118           -0.176023       3.894239         0.957868           -0.500540
# 122           -0.176023      -0.381424         0.447704           -0.470398
#
#      PANO1 (101927423)  HRURF (120766137)  PRRC2B (84726)  F8A2 (474383)  \
# 36            0.485490          -0.033758        0.051212       0.490344
# 84           -0.373958          -0.033758        0.314574       0.452101
# 103          -0.150914          -0.033758       -0.229838      -0.705923
# 118           1.287086          -0.033758        1.326406       0.025958
# 122          -0.024186          -0.033758        1.652498      -0.656863
#
#      F8A1 (8263)  Z_SCORE_PUBLISHED
# 36     -0.821658           1.966718
# 84     -0.111954           1.062881
# 103     0.708643          -0.010455
# 118     1.037985           0.880385
# 122     0.611085           1.909326
#
# [5 rows x 19216 columns]

# %%
corrs_flat = corr_mat[['Z_SCORE_PUBLISHED']][lambda x: x.index != 'Z_SCORE_PUBLISHED'].values

plt.figure()
sbn.histplot(corrs_flat, bins=100)
plt.xlabel('Spearman correlation')
plt.ylabel('Frequency')
plt.title('Distribution of Spearman correlations')
plt.show()

# %%
(corrs_flat < -0.18).mean()
# Out:
# np.float64(0.2545407233931824)

# %%
(corrs_flat < -0.48).mean()
# Out:
# np.float64(0.024824355971896955)

# %%
(corrs_flat < -0.59).mean()
# Out:
# np.float64(0.004475670049440541)

# %%
max_corr = corrs_flat.max()

# %%
corr_mat.iloc[(corr_mat.values == max_corr).nonzero()]
# Out:
#                    hsa-miR-890  Z_SCORE_PUBLISHED  hsa-let-7b  hsa-miR-342-3p
# hsa-let-7b            0.716725          -0.073693    1.000000        0.296167
# hsa-miR-342-3p        0.145819           0.716725    0.296167        1.000000
# hsa-miR-890           1.000000           0.042857    0.716725        0.145819
# Z_SCORE_PUBLISHED     0.042857           1.000000   -0.073693        0.716725
